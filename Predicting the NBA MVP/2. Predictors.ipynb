# %%
# Predictors [2/3]

# %%
import pandas as pd

# %%
mvps = pd.read_csv("mvps.csv", index_col=0)

# %%
mvps
# Out:
#    Rank             Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0     1     Michael Jordan   27  CHI   77.0    891.0      960  0.928  82
# 1     2      Magic Johnson   31  LAL   10.0    497.0      960  0.518  79
# 2     3     David Robinson   25  SAS    6.0    476.0      960  0.496  82
# 3     4    Charles Barkley   27  PHI    2.0    222.0      960  0.231  67
# 4     5        Karl Malone   27  UTA    0.0    142.0      960  0.148  82
# ..  ...                ...  ...  ...    ...      ...      ...    ...  ..
# 10   11  Russell Westbrook   32  WAS    0.0      5.0     1010  0.005  65
# 11   12        Ben Simmons   24  PHI    0.0      3.0     1010  0.003  58
# 12  13T       James Harden   31  TOT    0.0      1.0     1010  0.001  44
# 13  13T       LeBron James   36  LAL    0.0      1.0     1010  0.001  45
# 14  13T      Kawhi Leonard   29  LAC    0.0      1.0     1010  0.001  52
#
#       MP  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  Year
# 0   37.0  ...   6.0   5.5  2.7  1.0  0.539  0.312  0.851  20.3  0.321  1991
# 1   37.1  ...   7.0  12.5  1.3  0.2  0.477  0.320  0.906  15.4  0.251  1991
# 2   37.7  ...  13.0   2.5  1.5  3.9  0.552  0.143  0.762  17.0  0.264  1991
# 3   37.3  ...  10.1   4.2  1.6  0.5  0.570  0.284  0.722  13.4  0.258  1991
# 4   40.3  ...  11.8   3.3  1.1  1.0  0.527  0.286  0.770  15.5  0.225  1991
# ..   ...  ...   ...   ...  ...  ...    ...    ...    ...   ...    ...   ...
# 10  36.4  ...  11.5  11.7  1.4  0.4  0.439  0.315  0.656   3.7  0.075  2021
# 11  32.4  ...   7.2   6.9  1.6  0.6  0.557  0.300  0.613   6.0  0.153  2021
# 12  36.6  ...   7.9  10.8  1.2  0.8  0.466  0.362  0.861   7.0  0.208  2021
# 13  33.4  ...   7.7   7.8  1.1  0.6  0.513  0.365  0.698   5.6  0.179  2021
# 14  34.1  ...   6.5   5.2  1.6  0.4  0.512  0.398  0.885   8.8  0.238  2021
#
# [474 rows x 21 columns]

# %%
players = pd.read_csv("players.csv", index_col=0)

# %%
players
# Out:
#       Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0      1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  ...  0.6
# 1      2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  ...  0.5
# 2      3          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  ...  2.1
# 3      4       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  ...  0.9
# 4      5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  ...  1.7
# ..   ...                 ...  ..  ..  ...  ..  ..   ...  ...   ...  ...  ...
# 725  536        Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3  ...  1.0
# 726  537      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  ...  2.5
# 727  538          Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  ...  0.6
# 728  539         Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  ...  2.5
# 729  540         Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  ...  2.6
#
#      DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0    1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1    1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2    3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3    3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4    3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ..   ...  ...   ...  ...  ...  ...  ...   ...   ...
# 725  2.9  3.9   3.6  1.6  0.4  1.3  1.1  10.0  2021
# 726  3.8  6.2   4.3  1.1  0.6  2.0  2.2  12.1  2021
# 727  3.3  3.9   9.4  0.8  0.2  4.1  1.8  25.3  2021
# 728  4.4  6.8   1.8  0.6  0.4  1.1  2.5   9.4  2021
# 729  4.6  7.2   1.3  0.3  0.9  1.1  2.6   9.0  2021
#
# [18044 rows x 31 columns]

# %%
del players["Rk"]

# %%
players["Player"] = players["Player"].str.replace("*","", regex=False)
players.head()
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...  0.6
# 1  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...  0.5
# 2          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...  2.1
# 3       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...  0.9
# 4        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...  1.7
#
#    DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 30 columns]

# %%
players[players["Player"] == "Greg Anderson"]
# Out:
#            Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  DRB  \
# 8   Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4  3.3
# 8   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1  7.4
# 10  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4  5.0
# 9   Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2  2.5
# 8   Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6  1.5
# 10  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9  3.5
# 8   Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8  1.6
#
#      TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8    4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 8   11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 10   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 9    3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 8    2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 10   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# 8    2.4  0.3  0.4  0.2  0.3  1.7   1.8  1998
#
# [7 rows x 30 columns]

# %%
def single_team(df):
    if df.shape[0]==1:
        return df
    else:
        row = df[df["Tm"]=="TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row

players = players.groupby(["Player", "Year"]).apply(single_team)

# %%
players
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player         Year
# A.C. Green     1991 164      A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#                1992 174      A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#                1993 157      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#                1994 177      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#                1995 165      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
# ...                                 ...  ..  ..  ...  ..  ..   ...  ...   ...
# Željko Rebrača 2002 394  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1
#                2003 374  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8
#                2004 452  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2
#                2005 446  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0
#                2006 433  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3
#
#                           FG%  ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  \
# Player         Year            ...
# A.C. Green     1991 164  .476  ...  2.5  3.8  6.3  0.9  0.7  0.3  1.2  1.4
#                1992 174  .476  ...  3.7  5.6  9.3  1.4  1.1  0.4  1.4  1.7
#                1993 157  .537  ...  3.5  5.2  8.7  1.4  1.1  0.5  1.4  1.8
#                1994 177  .502  ...  3.4  5.8  9.2  1.7  0.9  0.5  1.2  1.7
#                1995 165  .504  ...  2.4  5.8  8.2  1.5  0.7  0.4  1.4  1.8
# ...                       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Željko Rebrača 2002 394  .505  ...  1.1  2.8  3.9  0.5  0.4  1.0  1.1  2.6
#                2003 374  .552  ...  0.9  2.2  3.1  0.3  0.2  0.6  1.0  2.6
#                2004 452  .442  ...  1.0  1.5  2.4  0.3  0.2  0.5  0.7  2.2
#                2005 446  .568  ...  0.8  2.3  3.2  0.4  0.2  0.7  0.8  2.2
#                2006 433  .542  ...  0.4  1.8  2.2  0.3  0.2  0.7  0.8  2.0
#
#                           PTS  Year
# Player         Year
# A.C. Green     1991 164   9.1  1991
#                1992 174  13.6  1992
#                1993 157  12.8  1993
#                1994 177  14.7  1994
#                1995 165  11.2  1995
# ...                       ...   ...
# Željko Rebrača 2002 394   6.9  2002
#                2003 374   6.6  2003
#                2004 452   3.8  2004
#                2005 446   5.8  2005
#                2006 433   4.7  2006
#
# [14092 rows x 30 columns]

# %%
players.index = players.index.droplevel()

# %%
players.head()
# Out:
#          Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  DRB  \
# 164  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  2.5  3.8
# 174  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  3.7  5.6
# 157  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  3.5  5.2
# 177  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  3.4  5.8
# 165  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  2.4  5.8
#
#      TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 164  6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991
# 174  9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992
# 157  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993
# 177  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994
# 165  8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995
#
# [5 rows x 30 columns]

# %%
players[players["Player"] == "Greg Anderson"]
# Out:
#            Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  DRB  \
# 8   Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4  3.3
# 8   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1  7.4
# 10  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4  5.0
# 9   Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2  2.5
# 8   Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6  1.5
# 10  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9  3.5
# 8   Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8  1.6
#
#      TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8    4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 8   11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 10   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 9    3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 8    2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 10   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# 8    2.4  0.3  0.4  0.2  0.3  1.7   1.8  1998
#
# [7 rows x 30 columns]

# %%
combined = players.merge(mvps, how="outer", on=["Player", "Year"])

# %%
combined[combined['Pts Won']>0]
# Out:
#               Player    Pos Age_x Tm_x G_x  GS  MP_x    FG   FGA FG%_x  ...  \
# 187     Al Jefferson      C    29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 329    Allen Iverson     PG    21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 331    Allen Iverson     SG    23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 332    Allen Iverson     SG    24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 333    Allen Iverson     SG    25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...   ...  ...  ..  ..   ...   ...   ...   ...  ...
# 13587   Vince Carter     SF    23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 13588   Vince Carter     SF    24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 13592   Vince Carter  SF-SG    28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 13952       Yao Ming      C    23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 13957       Yao Ming      C    28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#       PTS_y TRB_y AST_y STL_y BLK_y  FG%_y  3P%_y  FT%_y    WS  WS/48
# 187    21.8  10.8   2.1   0.9   1.1  0.509  0.200  0.690   7.8  0.146
# 329    23.5   4.1   7.5   2.1   0.3  0.416  0.341  0.702   4.1  0.065
# 331    26.8   4.9   4.6   2.3   0.1  0.412  0.291  0.751   7.2  0.173
# 332    28.4   3.8   4.7   2.1   0.1  0.421  0.341  0.713   6.9  0.116
# 333    31.1   3.8   4.6   2.5   0.3  0.420  0.320  0.814  11.8  0.190
# ...     ...   ...   ...   ...   ...    ...    ...    ...   ...    ...
# 13587  25.7   5.8   3.9   1.3   1.1  0.465  0.403  0.791  11.8  0.182
# 13588  27.6   5.5   3.9   1.5   1.1  0.460  0.408  0.765  12.9  0.208
# 13592  24.5   5.2   4.2   1.4   0.6  0.452  0.406  0.798   9.4  0.159
# 13952  17.5   9.0   1.5   0.3   1.9  0.522  0.000  0.809  11.4  0.202
# 13957  19.7   9.9   1.8   0.4   1.9  0.548  1.000  0.866  10.6  0.196
#
# [474 rows x 49 columns]

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined.columns
# Out:
# Index(['Player', 'Pos', 'Age_x', 'Tm_x', 'G_x', 'GS', 'MP_x', 'FG', 'FGA',
#        'FG%_x', '3P', '3PA', '3P%_x', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%_x', 'ORB', 'DRB', 'TRB_x', 'AST_x', 'STL_x', 'BLK_x', 'TOV', 'PF',
#        'PTS_x', 'Year', 'Rank', 'Age_y', 'Tm_y', 'First', 'Pts Won', 'Pts Max',
#        'Share', 'G_y', 'MP_y', 'PTS_y', 'TRB_y', 'AST_y', 'STL_y', 'BLK_y',
#        'FG%_y', '3P%_y', 'FT%_y', 'WS', 'WS/48'],
#       dtype='object')

# %%
teams = pd.read_csv("teams.csv")
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  56  26  .683     —  111.5  105.7   5.22  1991
# 1              1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2              2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3              3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4              4  26  56  .317  30.0  102.9  107.5  -4.53  1991
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1028          13  42  30  .583     —  112.4  110.2   2.26  2021
# 1029          14  38  34  .528   4.0  113.3  112.3   1.07  2021
# 1030          15  33  39  .458   9.0  111.1  112.8  -1.58  2021
# 1031          16  31  41  .431  11.0  114.6  114.9  -0.20  2021
# 1032          17  17  55  .236  25.0  108.8  116.7  -7.50  2021
#
#                       Team
# 0          Boston Celtics*
# 1      Philadelphia 76ers*
# 2         New York Knicks*
# 3       Washington Bullets
# 4          New Jersey Nets
# ...                    ...
# 1028     Dallas Mavericks*
# 1029    Memphis Grizzlies*
# 1030     San Antonio Spurs
# 1031  New Orleans Pelicans
# 1032       Houston Rockets
#
# [1033 rows x 10 columns]

# %%
teams = teams[~teams["W"].str.contains("Division")].copy()
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)
sorted(teams["Team"].unique())
# Out:
# ['Atlanta Hawks',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Charlotte Bobcats',
#  'Charlotte Hornets',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Detroit Pistons',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Indiana Pacers',
#  'Los Angeles Clippers',
#  'Los Angeles Lakers',
#  'Memphis Grizzlies',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'Minnesota Timberwolves',
#  'New Jersey Nets',
#  'New Orleans Hornets',
#  'New Orleans Pelicans',
#  'New Orleans/Oklahoma City Hornets',
#  'New York Knicks',
#  'Oklahoma City Thunder',
#  'Orlando Magic',
#  'Philadelphia 76ers',
#  'Phoenix Suns',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'San Antonio Spurs',
#  'Seattle SuperSonics',
#  'Toronto Raptors',
#  'Utah Jazz',
#  'Vancouver Grizzlies',
#  'Washington Bullets',
#  'Washington Wizards']

# %%
sorted(combined["Tm"].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [57], line 1
# ----> 1 sorted(combined["Tm"].unique())
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Tm'

# %%
nicknames = {}
with open("nicknames.csv") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev,name = line.replace("\n","").split(",")
        nicknames[abbrev] = name

# %%
combined['Team'] = combined["Tm"].map(nicknames)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [49], line 1
# ----> 1 combined['Team'] = combined["Tm"].map(nicknames)
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Tm'

# %%
combined.head()
# Out:
#        Player Pos Age_x Tm_x G_x  GS  MP_x   FG   FGA FG%_x  ... PTS_y TRB_y  \
# 0  A.C. Green  PF    27  LAL  82  21  26.4  3.1   6.6  .476  ...   NaN   NaN
# 1  A.C. Green  PF    28  LAL  82  53  35.4  4.7   9.8  .476  ...   NaN   NaN
# 2  A.C. Green  PF    29  LAL  82  55  34.4  4.6   8.6  .537  ...   NaN   NaN
# 3  A.C. Green  PF    30  PHO  82  55  34.5  5.7  11.3  .502  ...   NaN   NaN
# 4  A.C. Green  SF    31  PHO  82  52  32.8  3.8   7.5  .504  ...   NaN   NaN
#
#   AST_y STL_y BLK_y FG%_y 3P%_y FT%_y  WS WS/48
# 0   NaN   NaN   NaN   NaN   NaN   NaN NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN NaN   NaN
#
# [5 rows x 49 columns]

# %%
train = combined.merge(teams, how="outer",on=["Team", "Year"])
train = train.apply(pd.to_numeric, errors='ignore')
train = train.apply(pd.to_numeric, errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [60], line 1
# ----> 1 train = combined.merge(teams, how="outer",on=["Team", "Year"])
#       2 train = train.apply(pd.to_numeric, errors='ignore')
#       3 train = train.apply(pd.to_numeric, errors='ignore')
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
#    9355         suffixes=suffixes,
#    9356         copy=copy,
#    9357         indicator=indicator,
#    9358         validate=validate,
#    9359     )
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\reshape\merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     693 self._cross = cross_col
#     695 # note this function has side effects
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
# --> 700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
#     704 self._maybe_coerce_merge_keys()
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\reshape\merge.py:1110, in _MergeOperation._get_merge_keys(self)
#    1108     right_keys.append(rk)
#    1109 if lk is not None:
# -> 1110     left_keys.append(left._get_label_or_level_values(lk))
#    1111     join_names.append(lk)
#    1112 else:
#    1113     # work-around for merge_asof(left_index=True)
#
# File ~\.conda\envs\GSPT\lib\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'Team'

# %%
train = train.apply(pd.to_numeric, errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 train = train.apply(pd.to_numeric, errors='ignore')
#
# NameError: name 'train' is not defined

# %%
train["GB"] = pd.to_numeric(train["GB"].str.replace("—","0"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [62], line 1
# ----> 1 train["GB"] = pd.to_numeric(train["GB"].str.replace("—","0"))
#
# NameError: name 'train' is not defined

# %%
train.to_csv("player_mvp_stats.csv")
highest_scoring = train[train["G"] > 70].sort_values("PTS", ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 train.to_csv("player_mvp_stats.csv")
#
# NameError: name 'train' is not defined

# %%
highest_scoring.plot.bar("Player", "PTS")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [64], line 1
# ----> 1 highest_scoring.plot.bar("Player", "PTS")
#
# NameError: name 'highest_scoring' is not defined

# %%
highest_scoring_by_year = train.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))
highest_scoring_by_year.plot.bar("Year", "PTS")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [65], line 1
# ----> 1 highest_scoring_by_year = train.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))
#       2 highest_scoring_by_year.plot.bar("Year", "PTS")
#
# NameError: name 'train' is not defined

# %%
train.groupby("Year").apply(lambda x: x.shape[0])

# %%
train.corr()["Share"]

# %%
train.corr()["Share"].plot.bar()
